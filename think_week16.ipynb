# %% [markdown]
# <a href="https://colab.research.google.com/github/kimmmmmmmm208/Computational-Thinking-and-Program-Design/blob/master/think_week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("為了解開爸爸的死亡之謎，我透過老先生介紹，前往許墨教授的實驗室。")
print("叩叩叩~")
print("許墨：「請進~」")
print("許墨：「請問你是?」")
name = input("你的名字?")
print("我：我叫做",name,"。")
print("許墨：「啊，原來是",name,"啊，是那位老先生介紹的吧，他是我爸。」")
print("我：「原來是這樣啊。」")
print("許墨：「咦，",name,"今年幾歲啊?」")
age = float(input("你的年齡?"))
aged = 25 - age
if aged > 0:
  print("許墨：「原來是妹妹啊，我大你",aged,"歲，你可以叫我許哥哥哦。」")
elif aged < 0:
  aged = -aged
  print("許墨：「原來是姊姊啊，我小你",aged,"歲，你叫我許墨就好了。」")
elif aged == 0:
  print("許墨 :「我也",age,"歲呢，你叫我許墨就好了。」")
print("我：「好的。」")
print("許墨：「那你住哪裡呢?」")
address = input("你住哪裡?")
print("我：「我住在",address,"。」")
print("許墨：「那我送妳回去好了，路上再說說你想知道的事吧。」")
print("/")
print("許墨：「請問你爸爸的名字是?」")
namef = input("你爸爸的名字是?")
print("我：「",namef,"。」")
print("啊，原來是那位前輩阿，我前幾年參加節目時有看到過呢。")
print("許墨：「對了，我家也剛好住在你家附近，因為想要好好的討論關於你爸的是，你介意來我家裡嗎?但那裡有我一個朋友，不知道你會不會覺得尷尬。」")
ans1 = float(input("不介意=0/介意=1"))
if ans1 == 1:
  print("許墨：「那沒關係，我們在附近的咖啡廳聊聊就好了。」")
  print("觸發事件失敗，Game over。")
elif ans1 == 0:
  print("許墨：「那我們走吧。」")
  print("/")
  print("回家了~")
  print("一開門，一個黃色頭髮的可愛生物就撲到許墨教授身上。")
  print("周棋洛：「墨~~~好想你哦!」")
  print("許墨：「不好意思，",name,"我另一個朋友不請自來了，你不會介意吧?」")
  ans2 = float(input("不介意=0/介意=1"))
  if ans2 == 1:
    print("許墨：「沒關係，我馬上就把他趕出去。」")
    print("周棋洛是這次事件的重要角色，但卻被許墨趕走了，Game over。")
  if ans2 == 0:
    print("周棋洛：「我就知道",name,"是個好人，我們來做朋友吧!」")
    print("這時一直站在後面的人說話了。")
    print("白起：「天啊",name,"好久不見!」")
    print("許墨：「你們認識嗎?」")
    print("白起：「他是我高中同學」")
    print("許墨：「",name,"是什麼高中的呢?」")
    school = input("你的高中?")
    print("許墨：「我也是那個高中的呢，那你要叫我什麼呢?」")
    print("我：「學長好。」")
    print("許墨：「乖，好了，我要來辦正事了。」")
    print("因為周棋洛一直黏在許墨教授身上，所以教授似乎想把他趕出去。")
    print("周棋洛一臉小狗可憐樣的看著許墨。")
    print("墨~不要這樣對偶QQ",name,"小姐，我記得我有在便利商店看過你耶，你是不是在那裡買了薯片呀?")
    ans3 = float(input("不是=0/是=1"))
    if ans3 == 0:
      print("周棋洛：「啊，原來是這樣啊，我還以為那個人是你呢......」")
      print("周棋洛好感度歸零，Game over。")
    elif ans3 ==1:
      print("我：「你怎麼知道」")
      print("周棋洛：「因為你搶了我的薯片!薯片小姐!你這樣剛剛還想要讓墨趕我走嗎?」")
      print("我：「我沒有......」")
      print("周棋洛 :「沒關係，那之後我想吃薯片的話，你可以跟我一起去吃嗎?」")
      ans4 = float(input("不要=0/好=1"))
      if ans4 == 0:
        print("周棋洛好感度歸零，Game over。")
      elif ans4 == 1:
        print("任務完成!")
# Out:
# 為了解開爸爸的死亡之謎，我透過老先生介紹，前往許墨教授的實驗室。
# 叩叩叩~
# 許墨：「請進~」
# 許墨：「請問你是?」
# 你的名字?55
# 我：我叫做 55 。
# 許墨：「啊，原來是 55 啊，是那位老先生介紹的吧，他是我爸。」
# 我：「原來是這樣啊。」
# 許墨：「咦， 55 今年幾歲啊?」
# 你的年齡?5
# 許墨：「原來是妹妹啊，我大你 20.0 歲，你可以叫我許哥哥哦。」
# 我：「好的。」
# 許墨：「那你住哪裡呢?」
# 你住哪裡?5
# 我：「我住在 5 。」
# 許墨：「那我送妳回去好了，路上再說說你想知道的事吧。」
# /
# 許墨：「請問你爸爸的名字是?」
# 你爸爸的名字是?5
# 我：「 5 。」
# 啊，原來是那位前輩阿，我前幾年參加節目時有看到過呢。
# 許墨：「對了，我家也剛好住在你家附近，因為想要好好的討論關於你爸的是，你介意來我家裡嗎?但那裡有我一個朋友，不知道你會不會覺得尷尬。」
# 不介意=0/介意=10
# 許墨：「那我們走吧。」
# /
# 回家了~
# 一開門，一個黃色頭髮的可愛生物就撲到許墨教授身上。
# 周棋洛：「墨~~~好想你哦!」
# 許墨：「不好意思， 55 我另一個朋友不請自來了，你不會介意吧?」
# 不介意=0/介意=10
# 周棋洛：「我就知道 55 是個好人，我們來做朋友吧!」
# 這時一直站在後面的人說話了。
# 白起：「天啊 55 好久不見!」
# 許墨：「你們認識嗎?」
# 白起：「他是我高中同學」
# 許墨：「 55 是什麼高中的呢?」
# 你的高中?0
# 許墨：「我也是那個高中的呢，那你要叫我什麼呢?」
# 我：「學長好。」
# 許墨：「乖，好了，我要來辦正事了。」
# 因為周棋洛一直黏在許墨教授身上，所以教授似乎想把他趕出去。
# 周棋洛一臉小狗可憐樣的看著許墨。
# 墨~不要這樣對偶QQ 55 小姐，我記得我有在便利商店看過你耶，你是不是在那裡買了薯片呀?
# 不是=0/是=11
# 我：「你怎麼知道」
# 周棋洛：「因為你搶了我的薯片!薯片小姐!你這樣剛剛還想要讓墨趕我走嗎?」
# 我：「我沒有......」
# 周棋洛 :「沒關係，那之後我想吃薯片的話，你可以跟我一起去吃嗎?」
# 不要=0/好=11
# 任務完成!
